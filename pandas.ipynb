# %% [markdown]
# <a href="https://colab.research.google.com/github/rahat-r404/Advance_Python/blob/master/pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Pandas

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd

# %%
colors = pd.Series(["Red", "Green", "Black"])

# %%
colors
# Out:
# 0      Red
# 1    Green
# 2    Black
# dtype: object

# %%
cars = pd.Series(["BMW", "Audi", "Toyota"])

# %%
cars
# Out:
# 0       BMW
# 1      Audi
# 2    Toyota
# dtype: object

# %%
car_data = pd.DataFrame({"Brand":cars, "Color":colors})

# %%
car_data
# Out:
#     Brand  Color
# 0     BMW    Red
# 1    Audi  Green
# 2  Toyota  Black

# %%
car_data.to_csv("/content/drive/MyDrive/Colab Notebooks/datasets/car_data.csv", index=True)

# %%
car_sales = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/datasets/car-sales.csv")
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %% [markdown]
# ## Describe Data

# %%
# Attribute
car_sales.dtypes

# Function
# car_sales.to_csv()
# Out:
# Make             object
# Colour           object
# Odometer (KM)     int64
# Doors             int64
# Price            object
# dtype: object

# %%
# Index
car_sales.index
# Out:
# RangeIndex(start=0, stop=10, step=1)

# %%
car_sales.describe()
# Out:
#        Odometer (KM)      Doors
# count      10.000000  10.000000
# mean    78601.400000   4.000000
# std     61983.471735   0.471405
# min     11179.000000   3.000000
# 25%     35836.250000   4.000000
# 50%     57369.000000   4.000000
# 75%     96384.500000   4.000000
# max    213095.000000   5.000000

# %%
car_sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Make           10 non-null     object
#  1   Colour         10 non-null     object
#  2   Odometer (KM)  10 non-null     int64
#  3   Doors          10 non-null     int64
#  4   Price          10 non-null     object
# dtypes: int64(2), object(3)
# memory usage: 528.0+ bytes

# %%
car_sales.mean()
# Out:
# <ipython-input-15-04f02239622f>:1: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   car_sales.mean()
# Odometer (KM)    78601.4
# Doors                4.0
# dtype: float64

# %%
car_sales.sum()
# Out:
# Make             ToyotaHondaToyotaBMWNissanToyotaHondaHondaToyo...
# Colour               WhiteRedBlueBlackWhiteGreenBlueBlueWhiteWhite
# Odometer (KM)                                               786014
# Doors                                                           40
# Price            $4,000.00$5,000.00$7,000.00$22,000.00$3,500.00...
# dtype: object

# %%
car_sales["Doors"].sum()
# Out:
# 40

# %%
car_sales.columns
# Out:
# Index(['Make', 'Colour', 'Odometer (KM)', 'Doors', 'Price'], dtype='object')

# %% [markdown]
# ## Viewing and Selecting Data

# %%
car_sales.head()
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00

# %%
car_sales.tail()
# Out:
#      Make Colour  Odometer (KM)  Doors      Price
# 5  Toyota  Green          99213      4  $4,500.00
# 6   Honda   Blue          45698      4  $7,500.00
# 7   Honda   Blue          54738      4  $7,000.00
# 8  Toyota  White          60000      4  $6,250.00
# 9  Nissan  White          31600      4  $9,700.00

# %%
car_sales.head(8)
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00

# %%
# .loc & .iloc
animals = pd.Series(["Cat", "Dog", "Bird", "Snake", "Fish"], index=[1, 2, 3, 3, 4])

# %%
animals
# Out:
# 1      Cat
# 2      Dog
# 3     Bird
# 3    Snake
# 4     Fish
# dtype: object

# %%
animals.loc[3]
# Out:
# 3     Bird
# 3    Snake
# dtype: object

# %%
animals
# Out:
# 1      Cat
# 2      Dog
# 3     Bird
# 3    Snake
# 4     Fish
# dtype: object

# %%
animals.iloc[2]
# Out:
# 'Bird'

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
car_sales.loc[3]
# Out:
# Make                    BMW
# Colour                Black
# Odometer (KM)         11179
# Doors                     5
# Price            $22,000.00
# Name: 3, dtype: object

# %%
car_sales.loc[:3]
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00

# %%
car_sales.iloc[:3]
# Out:
#      Make Colour  Odometer (KM)  Doors      Price
# 0  Toyota  White         150043      4  $4,000.00
# 1   Honda    Red          87899      4  $5,000.00
# 2  Toyota   Blue          32549      3  $7,000.00

# %%
# Selecting  Column
car_sales["Make"]
# Out:
# 0    Toyota
# 1     Honda
# 2    Toyota
# 3       BMW
# 4    Nissan
# 5    Toyota
# 6     Honda
# 7     Honda
# 8    Toyota
# 9    Nissan
# Name: Make, dtype: object

# %%
car_sales.Make
# Out:
# 0    Toyota
# 1     Honda
# 2    Toyota
# 3       BMW
# 4    Nissan
# 5    Toyota
# 6     Honda
# 7     Honda
# 8    Toyota
# 9    Nissan
# Name: Make, dtype: object

# %%
car_sales["Colour"]
# Out:
# 0    White
# 1      Red
# 2     Blue
# 3    Black
# 4    White
# 5    Green
# 6     Blue
# 7     Blue
# 8    White
# 9    White
# Name: Colour, dtype: object

# %%
car_sales[car_sales["Odometer (KM)"] > 100000]
# Out:
#      Make Colour  Odometer (KM)  Doors      Price
# 0  Toyota  White         150043      4  $4,000.00
# 4  Nissan  White         213095      4  $3,500.00

# %%
# Compare two column
pd.crosstab(car_sales["Make"], car_sales["Doors"])
# Out:
# Doors   3  4  5
# Make
# BMW     0  0  1
# Honda   0  3  0
# Nissan  0  2  0
# Toyota  1  3  0

# %%
# Compare more than two column
car_sales.groupby(["Make"]).mean()
# Out:
# <ipython-input-36-799d829761af>:2: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   car_sales.groupby(["Make"]).mean()
#         Odometer (KM)  Doors
# Make
# BMW      11179.000000   5.00
# Honda    62778.333333   4.00
# Nissan  122347.500000   4.00
# Toyota   85451.250000   3.75

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
car_sales[car_sales["Colour"] == "White"]
# Out:
#      Make Colour  Odometer (KM)  Doors      Price
# 0  Toyota  White         150043      4  $4,000.00
# 4  Nissan  White         213095      4  $3,500.00
# 8  Toyota  White          60000      4  $6,250.00
# 9  Nissan  White          31600      4  $9,700.00

# %%
car_sales["Odometer (KM)"].plot()
# Out:
# <Axes: >

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
car_sales["Doors"].plot()
# Out:
# <Axes: >

# %%
car_sales["Odometer (KM)"].hist()
# Out:
# <Axes: >

# %%
car_sales["Doors"].hist()
# Out:
# <Axes: >

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
car_sales["Price"].plot()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-45-83bf2f29b5a6> in <cell line: 1>()
# ----> 1 car_sales["Price"].plot()
#
# /usr/local/lib/python3.10/dist-packages/pandas/plotting/_core.py in __call__(self, *args, **kwargs)
#     998                     data.columns = label_name
#     999
# -> 1000         return plot_backend.plot(data, kind=kind, **kwargs)
#    1001
#    1002     __call__.__doc__ = __doc__
#
# /usr/local/lib/python3.10/dist-packages/pandas/plotting/_matplotlib/__init__.py in plot(data, kind, **kwargs)
#      69             kwargs["ax"] = getattr(ax, "left_ax", ax)
#      70     plot_obj = PLOT_CLASSES[kind](data, **kwargs)
# ---> 71     plot_obj.generate()
#      72     plot_obj.draw()
#      73     return plot_obj.result
#
# /usr/local/lib/python3.10/dist-packages/pandas/plotting/_matplotlib/core.py in generate(self)
# ...

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
#Remove $ , from price column then convert it from string to int
car_sales["Price"] = car_sales["Price"].str.replace("[\$\,]", "", regex=True)

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors     Price
# 0  Toyota  White         150043      4   4000.00
# 1   Honda    Red          87899      4   5000.00
# 2  Toyota   Blue          32549      3   7000.00
# 3     BMW  Black          11179      5  22000.00
# 4  Nissan  White         213095      4   3500.00
# 5  Toyota  Green          99213      4   4500.00
# 6   Honda   Blue          45698      4   7500.00
# 7   Honda   Blue          54738      4   7000.00
# 8  Toyota  White          60000      4   6250.00
# 9  Nissan  White          31600      4   9700.00

# %%
car_sales["Price"] = car_sales["Price"].str.replace(".00", "", regex=False).astype(int)

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price
# 0  Toyota  White         150043      4   4000
# 1   Honda    Red          87899      4   5000
# 2  Toyota   Blue          32549      3   7000
# 3     BMW  Black          11179      5  22000
# 4  Nissan  White         213095      4   3500
# 5  Toyota  Green          99213      4   4500
# 6   Honda   Blue          45698      4   7500
# 7   Honda   Blue          54738      4   7000
# 8  Toyota  White          60000      4   6250
# 9  Nissan  White          31600      4   9700

# %%
car_sales.to_csv("/content/drive/MyDrive/Colab Notebooks/datasets/car-sales-updated.csv", index=False)

# %%
car_sales["Price"].plot()
# Out:
# <Axes: >

# %%
car_sales.groupby(["Make"]).mean()
# Out:
# <ipython-input-53-b0a0096139ad>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   car_sales.groupby(["Make"]).mean()
#         Odometer (KM)  Doors    Price
# Make
# BMW      11179.000000   5.00  22000.0
# Honda    62778.333333   4.00   6500.0
# Nissan  122347.500000   4.00   6600.0
# Toyota   85451.250000   3.75   5437.5

# %% [markdown]
# ## Manipulating Data

# %%
car_sales["Make"].str.lower()
# Out:
# 0    toyota
# 1     honda
# 2    toyota
# 3       bmw
# 4    nissan
# 5    toyota
# 6     honda
# 7     honda
# 8    toyota
# 9    nissan
# Name: Make, dtype: object

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price
# 0  Toyota  White         150043      4   4000
# 1   Honda    Red          87899      4   5000
# 2  Toyota   Blue          32549      3   7000
# 3     BMW  Black          11179      5  22000
# 4  Nissan  White         213095      4   3500
# 5  Toyota  Green          99213      4   4500
# 6   Honda   Blue          45698      4   7500
# 7   Honda   Blue          54738      4   7000
# 8  Toyota  White          60000      4   6250
# 9  Nissan  White          31600      4   9700

# %%
car_sales["Make"] = car_sales["Make"].str.lower()

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price
# 0  toyota  White         150043      4   4000
# 1   honda    Red          87899      4   5000
# 2  toyota   Blue          32549      3   7000
# 3     bmw  Black          11179      5  22000
# 4  nissan  White         213095      4   3500
# 5  toyota  Green          99213      4   4500
# 6   honda   Blue          45698      4   7500
# 7   honda   Blue          54738      4   7000
# 8  toyota  White          60000      4   6250
# 9  nissan  White          31600      4   9700

# %%
car_sales_missing = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/datasets/car-sales-missing-data.csv")
car_sales_missing
# Out:
#      Make Colour  Odometer  Doors    Price
# 0  Toyota  White  150043.0    4.0   $4,000
# 1   Honda    Red   87899.0    4.0   $5,000
# 2  Toyota   Blue       NaN    3.0   $7,000
# 3     BMW  Black   11179.0    5.0  $22,000
# 4  Nissan  White  213095.0    4.0   $3,500
# 5  Toyota  Green       NaN    4.0   $4,500
# 6   Honda    NaN       NaN    4.0   $7,500
# 7   Honda   Blue       NaN    4.0      NaN
# 8  Toyota  White   60000.0    NaN      NaN
# 9     NaN  White   31600.0    4.0   $9,700

# %%
car_sales_missing["Odometer"].fillna(car_sales_missing["Odometer"].mean())
# Out:
# 0    150043.000000
# 1     87899.000000
# 2     92302.666667
# 3     11179.000000
# 4    213095.000000
# 5     92302.666667
# 6     92302.666667
# 7     92302.666667
# 8     60000.000000
# 9     31600.000000
# Name: Odometer, dtype: float64

# %%
car_sales_missing
# Out:
#      Make Colour  Odometer  Doors    Price
# 0  Toyota  White  150043.0    4.0   $4,000
# 1   Honda    Red   87899.0    4.0   $5,000
# 2  Toyota   Blue       NaN    3.0   $7,000
# 3     BMW  Black   11179.0    5.0  $22,000
# 4  Nissan  White  213095.0    4.0   $3,500
# 5  Toyota  Green       NaN    4.0   $4,500
# 6   Honda    NaN       NaN    4.0   $7,500
# 7   Honda   Blue       NaN    4.0      NaN
# 8  Toyota  White   60000.0    NaN      NaN
# 9     NaN  White   31600.0    4.0   $9,700

# %%
car_sales_missing["Odometer"].fillna(car_sales_missing["Odometer"].mean(), inplace=True)

# %%
car_sales_missing
# Out:
#      Make Colour       Odometer  Doors    Price
# 0  Toyota  White  150043.000000    4.0   $4,000
# 1   Honda    Red   87899.000000    4.0   $5,000
# 2  Toyota   Blue   92302.666667    3.0   $7,000
# 3     BMW  Black   11179.000000    5.0  $22,000
# 4  Nissan  White  213095.000000    4.0   $3,500
# 5  Toyota  Green   92302.666667    4.0   $4,500
# 6   Honda    NaN   92302.666667    4.0   $7,500
# 7   Honda   Blue   92302.666667    4.0      NaN
# 8  Toyota  White   60000.000000    NaN      NaN
# 9     NaN  White   31600.000000    4.0   $9,700

# %%
car_sales_missing.dropna()
# Out:
#      Make Colour       Odometer  Doors    Price
# 0  Toyota  White  150043.000000    4.0   $4,000
# 1   Honda    Red   87899.000000    4.0   $5,000
# 2  Toyota   Blue   92302.666667    3.0   $7,000
# 3     BMW  Black   11179.000000    5.0  $22,000
# 4  Nissan  White  213095.000000    4.0   $3,500
# 5  Toyota  Green   92302.666667    4.0   $4,500

# %%
car_sales_missing.dropna(inplace=True)

# %%
car_sales_missing
# Out:
#      Make Colour       Odometer  Doors    Price
# 0  Toyota  White  150043.000000    4.0   $4,000
# 1   Honda    Red   87899.000000    4.0   $5,000
# 2  Toyota   Blue   92302.666667    3.0   $7,000
# 3     BMW  Black   11179.000000    5.0  $22,000
# 4  Nissan  White  213095.000000    4.0   $3,500
# 5  Toyota  Green   92302.666667    4.0   $4,500

# %%
car_sales_missing = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/datasets/car-sales-missing-data.csv")
car_sales_missing
# Out:
#      Make Colour  Odometer  Doors    Price
# 0  Toyota  White  150043.0    4.0   $4,000
# 1   Honda    Red   87899.0    4.0   $5,000
# 2  Toyota   Blue       NaN    3.0   $7,000
# 3     BMW  Black   11179.0    5.0  $22,000
# 4  Nissan  White  213095.0    4.0   $3,500
# 5  Toyota  Green       NaN    4.0   $4,500
# 6   Honda    NaN       NaN    4.0   $7,500
# 7   Honda   Blue       NaN    4.0      NaN
# 8  Toyota  White   60000.0    NaN      NaN
# 9     NaN  White   31600.0    4.0   $9,700

# %%
car_sales_missing_dropped = car_sales_missing.dropna()

# %%
car_sales_missing_dropped
# Out:
#      Make Colour  Odometer  Doors    Price
# 0  Toyota  White  150043.0    4.0   $4,000
# 1   Honda    Red   87899.0    4.0   $5,000
# 3     BMW  Black   11179.0    5.0  $22,000
# 4  Nissan  White  213095.0    4.0   $3,500

# %%
car_sales_missing_dropped.to_csv("/content/drive/MyDrive/Colab Notebooks/datasets/car-sales-missing-dropped.csv")

# %%
# Column from Series
seat_column = pd.Series([5, 5, 5, 5, 5])

# Add New Column to car_sales data
car_sales["Seats"] = seat_column
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  Seats
# 0  toyota  White         150043      4   4000    5.0
# 1   honda    Red          87899      4   5000    5.0
# 2  toyota   Blue          32549      3   7000    5.0
# 3     bmw  Black          11179      5  22000    5.0
# 4  nissan  White         213095      4   3500    5.0
# 5  toyota  Green          99213      4   4500    NaN
# 6   honda   Blue          45698      4   7500    NaN
# 7   honda   Blue          54738      4   7000    NaN
# 8  toyota  White          60000      4   6250    NaN
# 9  nissan  White          31600      4   9700    NaN

# %%
car_sales["Seats"].fillna(5, inplace=True)

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  Seats
# 0  toyota  White         150043      4   4000    5.0
# 1   honda    Red          87899      4   5000    5.0
# 2  toyota   Blue          32549      3   7000    5.0
# 3     bmw  Black          11179      5  22000    5.0
# 4  nissan  White         213095      4   3500    5.0
# 5  toyota  Green          99213      4   4500    5.0
# 6   honda   Blue          45698      4   7500    5.0
# 7   honda   Blue          54738      4   7000    5.0
# 8  toyota  White          60000      4   6250    5.0
# 9  nissan  White          31600      4   9700    5.0

# %%
# Column from python list
fuel_economy = [7.5, 9.2, 6.8, 9.9, 8.7, 4.6, 7.8, 8.6, 9.4, 10.1]
car_sales["Fuel Economy"] = fuel_economy
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  Seats  Fuel Economy
# 0  toyota  White         150043      4   4000    5.0           7.5
# 1   honda    Red          87899      4   5000    5.0           9.2
# 2  toyota   Blue          32549      3   7000    5.0           6.8
# 3     bmw  Black          11179      5  22000    5.0           9.9
# 4  nissan  White         213095      4   3500    5.0           8.7
# 5  toyota  Green          99213      4   4500    5.0           4.6
# 6   honda   Blue          45698      4   7500    5.0           7.8
# 7   honda   Blue          54738      4   7000    5.0           8.6
# 8  toyota  White          60000      4   6250    5.0           9.4
# 9  nissan  White          31600      4   9700    5.0          10.1

# %%
car_sales["Total Fuel Used (L)"] = car_sales["Odometer (KM)"]/100 * car_sales["Fuel Economy"]
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  Seats  Fuel Economy  \
# 0  toyota  White         150043      4   4000    5.0           7.5
# 1   honda    Red          87899      4   5000    5.0           9.2
# 2  toyota   Blue          32549      3   7000    5.0           6.8
# 3     bmw  Black          11179      5  22000    5.0           9.9
# 4  nissan  White         213095      4   3500    5.0           8.7
# 5  toyota  Green          99213      4   4500    5.0           4.6
# 6   honda   Blue          45698      4   7500    5.0           7.8
# 7   honda   Blue          54738      4   7000    5.0           8.6
# 8  toyota  White          60000      4   6250    5.0           9.4
# 9  nissan  White          31600      4   9700    5.0          10.1
#
#    Total Fuel Used (L)
# 0            11253.225
# 1             8086.708
# 2             2213.332
# 3             1106.721
# 4            18539.265
# 5             4563.798
# 6             3564.444
# 7             4707.468
# ...

# %%
# Create a column from a single value
car_sales["Number of Wheels"] = 4
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  Seats  Fuel Economy  \
# 0  toyota  White         150043      4   4000    5.0           7.5
# 1   honda    Red          87899      4   5000    5.0           9.2
# 2  toyota   Blue          32549      3   7000    5.0           6.8
# 3     bmw  Black          11179      5  22000    5.0           9.9
# 4  nissan  White         213095      4   3500    5.0           8.7
# 5  toyota  Green          99213      4   4500    5.0           4.6
# 6   honda   Blue          45698      4   7500    5.0           7.8
# 7   honda   Blue          54738      4   7000    5.0           8.6
# 8  toyota  White          60000      4   6250    5.0           9.4
# 9  nissan  White          31600      4   9700    5.0          10.1
#
#    Total Fuel Used (L)  Number of Wheels
# 0            11253.225                 4
# 1             8086.708                 4
# 2             2213.332                 4
# 3             1106.721                 4
# ...

# %%
car_sales["Passed Road Safety"] = True
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  Seats  Fuel Economy  \
# 0  toyota  White         150043      4   4000    5.0           7.5
# 1   honda    Red          87899      4   5000    5.0           9.2
# 2  toyota   Blue          32549      3   7000    5.0           6.8
# 3     bmw  Black          11179      5  22000    5.0           9.9
# 4  nissan  White         213095      4   3500    5.0           8.7
# 5  toyota  Green          99213      4   4500    5.0           4.6
# 6   honda   Blue          45698      4   7500    5.0           7.8
# 7   honda   Blue          54738      4   7000    5.0           8.6
# 8  toyota  White          60000      4   6250    5.0           9.4
# 9  nissan  White          31600      4   9700    5.0          10.1
#
#    Total Fuel Used (L)  Number of Wheels  Passed Road Safety
# 0            11253.225                 4                True
# 1             8086.708                 4                True
# ...

# %%
car_sales = car_sales.drop("Total Fuel Used", axis=1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-77-56e043d33434> in <cell line: 1>()
# ----> 1 car_sales = car_sales.drop("Total Fuel Used", axis=1)
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     329                     stacklevel=find_stack_level(),
#     330                 )
# --> 331             return func(*args, **kwargs)
#     332
#     333         # error: "Callable[[VarArg(Any), KwArg(Any)], Any]" has no
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    5397                 weight  1.0     0.8
#    5398         """
# -> 5399         return super().drop(
#    5400             labels=labels,
#    5401             axis=axis,
#
# ...

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  Seats  Fuel Economy  \
# 0  toyota  White         150043      4   4000    5.0           7.5
# 1   honda    Red          87899      4   5000    5.0           9.2
# 2  toyota   Blue          32549      3   7000    5.0           6.8
# 3     bmw  Black          11179      5  22000    5.0           9.9
# 4  nissan  White         213095      4   3500    5.0           8.7
# 5  toyota  Green          99213      4   4500    5.0           4.6
# 6   honda   Blue          45698      4   7500    5.0           7.8
# 7   honda   Blue          54738      4   7000    5.0           8.6
# 8  toyota  White          60000      4   6250    5.0           9.4
# 9  nissan  White          31600      4   9700    5.0          10.1
#
#    Total Fuel Used (L)  Number of Wheels  Passed Road Safety
# 0            11253.225                 4                True
# 1             8086.708                 4                True
# ...

# %%
car_sales.sample(frac=0.5)
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  Seats  Fuel Economy  \
# 7   honda   Blue          54738      4   7000    5.0           8.6
# 9  nissan  White          31600      4   9700    5.0          10.1
# 4  nissan  White         213095      4   3500    5.0           8.7
# 5  toyota  Green          99213      4   4500    5.0           4.6
# 2  toyota   Blue          32549      3   7000    5.0           6.8
#
#    Total Fuel Used (L)  Number of Wheels  Passed Road Safety
# 7             4707.468                 4                True
# 9             3191.600                 4                True
# 4            18539.265                 4                True
# 5             4563.798                 4                True
# 2             2213.332                 4                True

# %%
car_sales.sample(frac=1)
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  Seats  Fuel Economy  \
#